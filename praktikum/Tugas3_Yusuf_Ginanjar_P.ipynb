# %% [markdown]
# ## Tugas 3 : Dasar Input Output, Operasi
# Nama: Yusuf Ginanjar Putra

# %%
nama_depan = input("Masukkan nama depan: ")
nama_belakang = input("Masukkan nama belakang: ")
tanggal_lahir = int(input("Masukkan tanggal lahir (tanpa bulan & tahun): "))
bulan_lahir = int(input("Masukkan bulan lahir: "))
tahun_lahir = int(input("Masukkan tahun lahir: "))

print("")
print("Nama saya adalah {} {}.".format(nama_depan, nama_belakang))
print("Saya lahir pada tanggal {}/{}/{}.".format(tanggal_lahir, bulan_lahir, tahun_lahir))
print("Saya berusia {} tahun.".format(2022 - tahun_lahir))
# Out:
# Masukkan nama depan: Yusuf
# Masukkan nama belakang: Ginanjar
# Masukkan tanggal lahir (tanpa bulan & tahun): 16
# Masukkan bulan lahir: 9
# Masukkan tahun lahir: 1993
#
# Nama saya adalah Yusuf Ginanjar .
# Saya lahir pada tanggal 16/9/1993.
# Saya berusia 29 tahun.
